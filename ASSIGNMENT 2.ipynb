# %% [markdown]
# # <u>ASSIGNMENT 2</u>:

# %% [markdown]
# ## Module 3: Control Structures in Python
# ### Task 1: Check if a Number is Even or Odd
# #### <u>Problem Statement:</u>  Write a Python program that:
# 1. 	Takes an integer input from the user.
# 2. 	Checks whether the number is even or odd using an if-else statement.
# 3. 	Displays the result accordingly.

# %%
x = int(input("Enter the number :"))
if x%2 == 0:
    print(f"{x} in an EVEN number")
else:
    print(f"{x} is an ODD number")
# Out:
# Enter the number : 5
# 5 is an ODD number

# %% [markdown]
# ### Task 2: Sum of Integers from 1 to 50 Using a Loop
# #### <u>Problem Statement:</u> Write a Python program that:
# 1.   Uses a 'for loop' to iterate over numbers from 1 to 50.
# 2.   Calculates the sum of all integers in this range.
# 3.   Displays the final sum.

# %% [markdown]
# ![Screenshot 2025-05-26 183007.png](attachment:666b7d5d-c1f6-4a32-ba85-ef46b85a9aa4.png)
# ![Screenshot 2025-05-26 183142.png](attachment:4de249bd-005c-478f-88c5-0ded5d540f18.png)

# %%
# Method : 1
## range(start, stop, step)
sum =0
for i in range(1,51):
    sum =sum +i

print(sum)
# Out:
# 1275

# %%
# Method : 2 please enter N = 50
def sum_of_natural_numbers (N):
    total = 0
    count = 1
    while count <= N:
        total += count
        count += 1
    return total

N = int(input("N :"))
result = sum_of_natural_numbers(N)
print(f"Sum of first {N} natural numbers : {result}")
# Out:
# N : 50
# Sum of first 50 natural numbers : 1275
